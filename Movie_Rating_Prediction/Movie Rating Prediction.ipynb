# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

df_movie = pd.read_csv(
    "IMDb Movies India.csv",
    encoding="latin1"
)

print(df_movie.columns)
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='str')

# %%
df_movie.dropna(inplace=True)

df_movie.head()
# Out:
#                                  Name    Year Duration  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                             #Yaaram  (2019)  110 min
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                           ...Yahaan  (2005)  142 min
# 8                  ?: A Question Mark  (2012)   82 min
#
#                        Genre  Rating  Votes        Director          Actor 1  \
# 1                      Drama     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3            Comedy, Romance     4.4     35      Ovais Khan          Prateik
# 5     Comedy, Drama, Musical     4.7    827    Rahul Rawail       Bobby Deol
# 6        Drama, Romance, War     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  Horror, Mystery, Thriller     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# ...

# %%
df_movie.shape
# Out:
# (5659, 10)

# %%
df_movie.describe()
# Out:
#             Rating
# count  5659.000000
# mean      5.898533
# std       1.381165
# min       1.100000
# 25%       5.000000
# 50%       6.100000
# 75%       6.900000
# max      10.000000

# %%
df_movie.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
import pandas as pd

df_rating = pd.read_csv(
    "IMDb Movies India.csv",
    encoding="cp1252"
)

df_rating.dropna(inplace=True)

print(df_rating.head(10))
# Out:
#                                   Name    Year Duration  \
# 1   #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                              #Yaaram  (2019)  110 min
# 5                 ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                            ...Yahaan  (2005)  142 min
# 8                   ?: A Question Mark  (2012)   82 min
# 9                             @Andheri  (2014)  116 min
# 10           1:1.6 An Ode to Lost Love  (2004)   96 min
# 11                1:13:7 Ek Tera Saath  (2016)  120 min
# 12                            100 Days  (1991)  161 min
# 13                           100% Love  (2012)  166 min
#
#                         Genre  Rating  Votes           Director  \
# 1                       Drama     7.0      8      Gaurav Bakshi
# 3             Comedy, Romance     4.4     35         Ovais Khan
# 5      Comedy, Drama, Musical     4.7    827       Rahul Rawail
# 6         Drama, Romance, War     7.4  1,086     Shoojit Sircar
# ...

# %%
df_rating.shape
# Out:
# (5659, 10)

# %%
df_rating.describe()
# Out:
#             Rating
# count  5659.000000
# mean      5.898533
# std       1.381165
# min       1.100000
# 25%       5.000000
# 50%       6.100000
# 75%       6.900000
# max      10.000000

# %%
df_rating.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
import pandas as pd

df_users = pd.read_csv(
    "IMDb Movies India.csv",
    encoding="cp1252"
)

df_users.dropna(inplace=True)
df_users.head(10)
# Out:
#                                   Name    Year Duration  \
# 1   #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                              #Yaaram  (2019)  110 min
# 5                 ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                            ...Yahaan  (2005)  142 min
# 8                   ?: A Question Mark  (2012)   82 min
# 9                             @Andheri  (2014)  116 min
# 10           1:1.6 An Ode to Lost Love  (2004)   96 min
# 11                1:13:7 Ek Tera Saath  (2016)  120 min
# 12                            100 Days  (1991)  161 min
# 13                           100% Love  (2012)  166 min
#
#                         Genre  Rating  Votes           Director  \
# 1                       Drama     7.0      8      Gaurav Bakshi
# 3             Comedy, Romance     4.4     35         Ovais Khan
# 5      Comedy, Drama, Musical     4.7    827       Rahul Rawail
# 6         Drama, Romance, War     7.4  1,086     Shoojit Sircar
# ...

# %%
df_users.shape
# Out:
# (5659, 10)

# %%
df_users.describe()
# Out:
#             Rating
# count  5659.000000
# mean      5.898533
# std       1.381165
# min       1.100000
# 25%       5.000000
# 50%       6.100000
# 75%       6.900000
# max      10.000000

# %%
print(df_users.columns)
# Out:
# Index(['Name', 'Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director',
#        'Actor 1', 'Actor 2', 'Actor 3'],
#       dtype='str')

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()

df_users['Genre'] = labelencoder.fit_transform(df_users['Genre'])

df_users.head()
# Out:
#                                  Name    Year Duration  Genre  Rating  Votes  \
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min    229     7.0      8
# 3                             #Yaaram  (2019)  110 min    184     4.4     35
# 5                ...Aur Pyaar Ho Gaya  (1997)  147 min    157     4.7    827
# 6                           ...Yahaan  (2005)  142 min    289     7.4  1,086
# 8                  ?: A Question Mark  (2012)   82 min    320     5.6    326
#
#          Director          Actor 1                 Actor 2          Actor 3
# 1   Gaurav Bakshi     Rasika Dugal          Vivek Ghamande    Arvind Jangid
# 3      Ovais Khan          Prateik              Ishita Raj  Siddhant Kapoor
# 5    Rahul Rawail       Bobby Deol  Aishwarya Rai Bachchan    Shammi Kapoor
# 6  Shoojit Sircar  Jimmy Sheirgill          Minissha Lamba   Yashpal Sharma
# 8   Allyson Patel        Yash Dave          Muntazir Ahmad     Kiran Bhatia

# %%
df_users.isna().sum()
# Out:
# Name        0
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df_data = pd.concat([df_movie, df_rating, df_users], axis=1)
df_data.dropna()
df_data.head(10)
# Out:
#                                   Name    Year Duration  \
# 1   #Gadhvi (He thought he was Gandhi)  (2019)  109 min
# 3                              #Yaaram  (2019)  110 min
# 5                 ...Aur Pyaar Ho Gaya  (1997)  147 min
# 6                            ...Yahaan  (2005)  142 min
# 8                   ?: A Question Mark  (2012)   82 min
# 9                             @Andheri  (2014)  116 min
# 10           1:1.6 An Ode to Lost Love  (2004)   96 min
# 11                1:13:7 Ek Tera Saath  (2016)  120 min
# 12                            100 Days  (1991)  161 min
# 13                           100% Love  (2012)  166 min
#
#                         Genre  Rating  Votes           Director  \
# 1                       Drama     7.0      8      Gaurav Bakshi
# 3             Comedy, Romance     4.4     35         Ovais Khan
# 5      Comedy, Drama, Musical     4.7    827       Rahul Rawail
# 6         Drama, Romance, War     7.4  1,086     Shoojit Sircar
# ...

# %%
df_data.shape
# Out:
# (5659, 30)

# %%
df2 = df_users.drop(["Name"], axis=1)

df2.head()
# Out:
#      Year Duration  Genre  Rating  Votes        Director          Actor 1  \
# 1  (2019)  109 min    229     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3  (2019)  110 min    184     4.4     35      Ovais Khan          Prateik
# 5  (1997)  147 min    157     4.7    827    Rahul Rawail       Bobby Deol
# 6  (2005)  142 min    289     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  (2012)   82 min    320     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# 5  Aishwarya Rai Bachchan    Shammi Kapoor
# 6          Minissha Lamba   Yashpal Sharma
# 8          Muntazir Ahmad     Kiran Bhatia

# %%
df2.describe()
# Out:
#              Genre       Rating
# count  5659.000000  5659.000000
# mean    171.728221     5.898533
# std     108.208770     1.381165
# min       0.000000     1.100000
# 25%      47.000000     5.000000
# 50%     184.000000     6.100000
# 75%     248.000000     6.900000
# max     375.000000    10.000000

# %%
df2.isna().sum()
# Out:
# Year        0
# Duration    0
# Genre       0
# Rating      0
# Votes       0
# Director    0
# Actor 1     0
# Actor 2     0
# Actor 3     0
# dtype: int64

# %%
df_final = df2.dropna()

# %%
df_final.shape
# Out:
# (5659, 9)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12,6))
sns.countplot(y=df_final['Genre'],
              order=df_final['Genre'].value_counts().index[:10])

plt.show()

# %%
import matplotlib.pyplot as plt

df_final['Rating'].plot.hist(bins=25)

plt.ylabel("Frequency")
plt.xlabel("Ratings")
plt.title("Distribution of Movie Ratings")

plt.show()

# %%
plt.figure(figsize=(8,5))
df_final['Rating'].plot.hist(bins=20)

plt.xlabel("Ratings")
plt.ylabel("Frequency")
plt.title("Distribution of Movie Ratings")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.histplot(df_final['Rating'], bins=20, kde=True)

plt.xlabel("Movie Rating")
plt.ylabel("Count")
plt.title("Distribution of Movie Ratings")
plt.show()

# %%
df_final['Rating'].plot.hist(bins=10)

plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.title("Distribution of Movie Ratings")
plt.show()

# %%
plt.figure(figsize=(12,6))

sns.countplot(
    y=df_final['Genre'],
    order=df_final['Genre'].value_counts().head(10).index
)

plt.title("Top 10 Genres")
plt.show()

# %%
df_final.head()
# Out:
#      Year Duration  Genre  Rating  Votes        Director          Actor 1  \
# 1  (2019)  109 min    229     7.0      8   Gaurav Bakshi     Rasika Dugal
# 3  (2019)  110 min    184     4.4     35      Ovais Khan          Prateik
# 5  (1997)  147 min    157     4.7    827    Rahul Rawail       Bobby Deol
# 6  (2005)  142 min    289     7.4  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  (2012)   82 min    320     5.6    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# 5  Aishwarya Rai Bachchan    Shammi Kapoor
# 6          Minissha Lamba   Yashpal Sharma
# 8          Muntazir Ahmad     Kiran Bhatia

# %%
print(df_final.columns)
# Out:
# Index(['Year', 'Duration', 'Genre', 'Rating', 'Votes', 'Director', 'Actor 1',
#        'Actor 2', 'Actor 3'],
#       dtype='str')

# %%
input = df_final.drop(['Rating'], axis=1)
target = df_final['Rating']

# %%
target.head()
# Out:
# 1    7.0
# 3    4.4
# 5    4.7
# 6    7.4
# 8    5.6
# Name: Rating, dtype: float64

# %%
input.head()
# Out:
#      Year Duration  Genre  Votes        Director          Actor 1  \
# 1  (2019)  109 min    229      8   Gaurav Bakshi     Rasika Dugal
# 3  (2019)  110 min    184     35      Ovais Khan          Prateik
# 5  (1997)  147 min    157    827    Rahul Rawail       Bobby Deol
# 6  (2005)  142 min    289  1,086  Shoojit Sircar  Jimmy Sheirgill
# 8  (2012)   82 min    320    326   Allyson Patel        Yash Dave
#
#                   Actor 2          Actor 3
# 1          Vivek Ghamande    Arvind Jangid
# 3              Ishita Raj  Siddhant Kapoor
# 5  Aishwarya Rai Bachchan    Shammi Kapoor
# 6          Minissha Lamba   Yashpal Sharma
# 8          Muntazir Ahmad     Kiran Bhatia

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df_final['Director'] = le.fit_transform(df_final['Director'])
df_final['Actor 1'] = le.fit_transform(df_final['Actor 1'])
df_final['Actor 2'] = le.fit_transform(df_final['Actor 2'])
df_final['Actor 3'] = le.fit_transform(df_final['Actor 3'])

# %%
input = df_final.drop(['Rating'], axis=1)
target = df_final['Rating']

# %%
print(input.dtypes)
# Out:
# Year          str
# Duration      str
# Genre       int64
# Votes         str
# Director    int64
# Actor 1     int64
# Actor 2     int64
# Actor 3     int64
# dtype: object

# %%
df_final['Year'] = df_final['Year'].astype(str).str.extract('(\d{4})')
df_final['Year'] = pd.to_numeric(df_final['Year'], errors='coerce')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\dell\AppData\Local\Temp\ipykernel_18464\375815337.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df_final['Year'] = df_final['Year'].astype(str).str.extract('(\d{4})')

# %%
input = df_final.drop(['Rating'], axis=1)
target = df_final['Rating']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, Y_train, Y_test = train_test_split(input, target, test_size=0.3)

# %%
print(Y_test)
# Out:
# 6226     4.5
# 1566     6.1
# 13593    1.9
# 920      2.8
# 10042    6.2
#         ...
# 1402     4.8
# 2463     7.7
# 8092     7.0
# 5863     4.2
# 4033     6.5
# Name: Rating, Length: 1698, dtype: float64

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    input,
    target,
    test_size=0.2,
    random_state=42
)

# %%
df_final['Votes'] = df_final['Votes'].astype(str)
df_final['Votes'] = df_final['Votes'].str.replace(',', '', regex=False)
df_final['Votes'] = pd.to_numeric(df_final['Votes'], errors='coerce')

# %%
df_final['Duration'] = df_final['Duration'].str.extract('(\d+)')
df_final['Duration'] = pd.to_numeric(df_final['Duration'])
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\dell\AppData\Local\Temp\ipykernel_18464\416868628.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df_final['Duration'] = df_final['Duration'].str.extract('(\d+)')

# %%
print(df_final['Duration'].dtype)
# Out:
# int64

# %%
input = df_final.drop(['Rating'], axis=1)
target = df_final['Rating']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    input,
    target,
    test_size=0.2,
    random_state=42
)

# %%
print(x_train.dtypes)
# Out:
# Year        int64
# Duration    int64
# Genre       int64
# Votes       int64
# Director    int64
# Actor 1     int64
# Actor 2     int64
# Actor 3     int64
# dtype: object

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score

print("R2 Score:", r2_score(y_test, y_pred))
# Out:
# R2 Score: 0.08929055052181278

# %%
print(input.shape)
print(target.shape)
# Out:
# (5659, 8)
# (5659,)

# %%
x_test = np.array(x_test)

# %%
model.predict(x_test)
# Out:
# c:\Python313\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([5.63033377, 5.84119076, 5.93058305, ..., 5.60661345, 5.62132497,
#        6.54181763], shape=(1132,))

# %%
print(Y_test)
# Out:
# 6226     4.5
# 1566     6.1
# 13593    1.9
# 920      2.8
# 10042    6.2
#         ...
# 1402     4.8
# 2463     7.7
# 8092     7.0
# 5863     4.2
# 4033     6.5
# Name: Rating, Length: 1698, dtype: float64
